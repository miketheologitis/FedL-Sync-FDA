# %%
import itertools
import json
import os
import argparse

# Define the parameter values
params = {
    "nn_name": ['LeNet-5'],
    "fda_name": ['synchronous', 'sketch', 'naive'],
    "batch_size": [32, 64],
    "theta": [0.5, 1.],
    "rtc_steps": [1],
    "num_clients": [5, 10, 15, 20, 25, 30, 35, 40, 45, 50, 60]
}

combinations = [
    dict(zip(params.keys(), values)) 
    for values in itertools.product(*params.values())
]

# %%
combinations
# Out:
# [{'nn_name': 'LeNet-5',
#   'fda_name': 'synchronous',
#   'batch_size': 32,
#   'theta': 0.5,
#   'rtc_steps': 1,
#   'num_clients': 5},
#  {'nn_name': 'LeNet-5',
#   'fda_name': 'synchronous',
#   'batch_size': 32,
#   'theta': 0.5,
#   'rtc_steps': 1,
#   'num_clients': 10},
#  {'nn_name': 'LeNet-5',
#   'fda_name': 'synchronous',
#   'batch_size': 32,
#   'theta': 0.5,
#   'rtc_steps': 1,
#   'num_clients': 15},
#  {'nn_name': 'LeNet-5',
#   'fda_name': 'synchronous',
#   'batch_size': 32,
#   'theta': 0.5,
#   'rtc_steps': 1,
#   'num_clients': 20},
#  {'nn_name': 'LeNet-5',
#   'fda_name': 'synchronous',
#   'batch_size': 32,
#   'theta': 0.5,
#   'rtc_steps': 1,
#   'num_clients': 25},
#  {'nn_name': 'LeNet-5',
#   'fda_name': 'synchronous',
#   'batch_size': 32,
#   'theta': 0.5,
#   'rtc_steps': 1,
#   'num_clients': 30},
#  {'nn_name': 'LeNet-5',
#   'fda_name': 'synchronous',
#   'batch_size': 32,
#   'theta': 0.5,
#   'rtc_steps': 1,
#   'num_clients': 35},
# ...
