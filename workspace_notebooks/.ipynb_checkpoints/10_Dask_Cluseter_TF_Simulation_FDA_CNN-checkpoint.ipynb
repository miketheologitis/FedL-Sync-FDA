# %%
import import_ipynb
import TF_Simulation_FDA_CNN as sim
# Out:
# importing Jupyter notebook from TF_Simulation_FDA_CNN.ipynb

# %%
#!python -m pip install "dask[complete]"

# %%
from dask.distributed import Client

client = Client()

client
# Out:
# C:\Users\miket\Anaconda3\envs\tf-212-dask\lib\site-packages\distributed\node.py:182: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 50992 instead
#   warnings.warn(
# <Client: 'tcp://127.0.0.1:50993' processes=4 threads=8, memory=23.88 GiB>

# %%
client.close()
